# %% [markdown]
# # Introduction
#
# Making figures here

# %%
import numpy as np
import matplotlib.pyplot as plt
#import funcs1 as f
import osmnx as ox
import networkx as nx
from multiprocessing import Pool
import csv
from datetime import datetime
import scipy.stats
import scipy.stats as s
import time as time
from scipy import optimize
import pickle
# %matplotlib inline


def find_first_hitting_time(C):
    try:
        return C.index(1.0)
    except ValueError:
        return len(C)-1

# %% [markdown]
# ### ER stats

# %%
from matplotlib.ticker import FormatStrFormatter
plt.figure(figsize=(12,9))

tick_size = 13
tick_sizey = 13
axis_size = 28
xaxis_size = 32
x_max = 100
label_size = 22
label_y_position = 1.10
ymax = 1
inset_size = 18
num_trials = 100;
mbar = 1
tick_size_x = 16
legend_size = 12



                          
#Histogram
filename = 'data/Ts_rw.txt'
Ts_rw = np.loadtxt(filename)
filename = 'data/Ts_td.txt'
Ts_td = np.loadtxt(filename)
opacity = 0.6
ax1 = plt.subplot(221)
plt.hist(Ts_rw,alpha=opacity,edgecolor='k',normed=True)
plt.hist(Ts_td, alpha=opacity,edgecolor='k',normed=True)
plt.xlabel('$T_1$', fontsize=axis_size)
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)
ax1.spines["top"].set_visible(False)  
ax1.spines["right"].set_visible(False)
ax1.text(-0.025, label_y_position, 'a', transform=ax1.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
legend = ax1.legend(['Random walk', 'Urban explorer'],prop={'size': legend_size},
                    fancybox=True)
plt.setp(legend.get_title(),fontsize=18)
ax1.vlines(max(Ts_rw),0,0.000075,linestyles='dashed',color='C0')
ax1.vlines(max(Ts_td),0,0.000075,linestyles='dashed',color='C1')


#C1(t)
Cs_rw = list(np.loadtxt('data/C100_rw.txt'))
Cs_td = list(np.loadtxt('data/C100_td.txt'))
T_rw = find_first_hitting_time(Cs_rw)
T_td = find_first_hitting_time(Cs_td)


ax2 = plt.subplot(222)
plt.rc('font', size=tick_size_x) 
plt.plot(Cs_rw[:T_rw]);plt.plot(Cs_td[:T_td])
plt.xticks(fontsize=tick_size) 
plt.yticks(fontsize=tick_size)
plt.xlabel('$ t $', fontsize=axis_size)
plt.ylabel('$ C_{100} $', fontsize=axis_size)
ax2.spines["top"].set_visible(False)  
ax2.spines["right"].set_visible(False)
ax2.text(-0.1, 1.075, 'b', transform=ax2.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
#ax2.vlines(T_rw,0,1,linestyles='dashed',color='C0')
#ax2.vlines(T_td,0,1,linestyles='dashed',color='C1')
ax2.ticklabel_format(style='sci', axis='x', scilimits=(0,0), fontsize=22, labelsize=18)



Cs_rw = list(np.loadtxt('data/C1_rw.txt'))
Cs_td = list(np.loadtxt('data/C1_td.txt'))
T_rw = find_first_hitting_time(Cs_rw)
T_td = find_first_hitting_time(Cs_td)

ax3 = plt.subplot(223)
plt.rc('font', size=tick_size_x) 
plt.plot(Cs_rw[:T_rw]);plt.plot(Cs_td[:T_td])
plt.xticks(fontsize=tick_size) 
plt.yticks(fontsize=tick_size)
plt.xlabel('$ t $', fontsize=axis_size)
plt.ylabel('$ C_{1} $', fontsize=axis_size)
ax3.spines["top"].set_visible(False)  
ax3.spines["right"].set_visible(False)
ax3.text(-0.1, 1.075, 'c', transform=ax3.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
#ax3.vlines(T_rw,0,1,linestyles='dashed',color='C0')
#ax3.vlines(T_td,0,1,linestyles='dashed',color='C1')
ax3.ticklabel_format(style='sci', axis='x', scilimits=(0,0), fontsize=22, labelsize=18)



#Vienna -- to be filled in
Cs_rw = list(np.loadtxt('data/C100_rw.txt'))
Cs_td = list(np.loadtxt('data/C100_td.txt'))
T_rw = find_first_hitting_time(Cs_rw)
T_td = find_first_hitting_time(Cs_td)
ax4 = plt.subplot(224)
plt.plot([i-j for i,j in zip(Cs_rw, Cs_td)])
plt.xlabel('$t$',fontsize=axis_size);plt.ylabel('$C_{100}^{RW} - C_{100}^{UE}$', fontsize=axis_size-4)
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)
ax4.spines["top"].set_visible(False)  
ax4.spines["right"].set_visible(False)
ax4.text(-0.1, label_y_position, 'd', transform=ax4.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
ax4.ticklabel_format(style='sci', axis='x', scilimits=(0,0), fontsize=22, labelsize=18)
#ax4.text(0.9, 0.15, 'Vienna', transform=ax4.transAxes,
#      fontsize=inset_size, va='top', ha='right')
#plt.xlabel('Day',fontsize=axis_size)



plt.tight_layout()
plt.savefig('data/ER_stats.png')

# %% [markdown]
# ### Ratio of T's

# %%
#Load data
meanTratioER = np.loadtxt('data/meanTratio_versus_mbar_ER.txt')
nsER = np.loadtxt('data/maxTration_ns.txt')

meanTratioSF = np.loadtxt('data/meanTratio_versus_mbar_SF.txt')
nsSF = np.loadtxt('data/maxTration_ns_SF.txt')

meanTratioBB = np.loadtxt('data/meanTratio_versus_mbar_BB.txt')
nsBB = np.loadtxt('data/maxTration_ns_BB.txt')

meanTratioGG = np.loadtxt('data/meanTratio_versus_mbar_GG.txt')
nsGG = np.loadtxt('data/maxTration_ns_GG.txt')

meanTratioCitation = np.loadtxt('data/meanTratio_versus_mbar_citation.txt')
ncCitation = np.loadtxt('data/maxTration_ns_citation.txt')

meanTratioManhattan = np.loadtxt('data/meanTratio_versus_mbar_NYC.txt')
nsManhattan = np.loadtxt('data/maxTration_ns_NYC.txt')


tick_size=12
axis_size = 22

#Histogram
plt.figure(figsize=(9,6))
ax1 = plt.subplot(111)
plt.plot(nsER,meanTratioER,'o-')
plt.plot(nsSF,meanTratioSF,'o-')
plt.plot(nsBB,meanTratioBB,'o-')
plt.plot(nsBB,meanTratioGG,'o-')
plt.plot(ncCitation,meanTratioCitation,'o-')
plt.plot(nsManhattan,meanTratioManhattan,'o-')
plt.xlabel('$\\bar{m}$',fontsize=axis_size)
plt.ylabel('$\\langle T \\rangle_{UE}$ / $\\langle T \\rangle_{RW}$',fontsize=axis_size)
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)
ax1.spines["top"].set_visible(False)  
ax1.spines["right"].set_visible(False)
#ax1.text(-0.025, label_y_position, 'a', transform=ax1.transAxes,
#      fontsize=label_size, fontweight='bold', va='top', ha='right')
legend = ax1.legend(['Erdos Renyi', 'Scale free','Barbell','2D Grid','Citation','Street network'],\
                    prop={'size': legend_size},fancybox=True)
plt.setp(legend.get_title(),fontsize=18)
plt.hlines(1,0,max(nsER),linestyle='dashed')


plt.savefig('data/meanTratio_versus_mbar_all_graphs.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b9d9ef7b288f> in <module>()
#      39 #ax1.text(-0.025, label_y_position, 'a', transform=ax1.transAxes,
#      40 #      fontsize=label_size, fontweight='bold', va='top', ha='right')
# ---> 41 legend = ax1.legend(['Erdos Renyi', 'Scale free','Barbell','2D Grid','Citation','Street network'],                    prop={'size': legend_size},fancybox=True)
#      42 plt.setp(legend.get_title(),fontsize=18)
#      43 plt.hlines(1,0,max(nsER),linestyle='dashed')
#
# NameError: name 'legend_size' is not defined

# %%
#Load data
meanTratioER = np.loadtxt('data/meanTratio_versus_mbar_ER.txt')
nsER = np.loadtxt('data/maxTration_ns.txt')

meanTratioSF = np.loadtxt('data/meanTratio_versus_mbar_SF.txt')
nsSF = np.loadtxt('data/maxTration_ns_SF.txt')

meanTratioBB = np.loadtxt('data/meanTratio_versus_mbar_BB.txt')
nsBB = np.loadtxt('data/maxTration_ns_BB.txt')

meanTratioGG = np.loadtxt('data/meanTratio_versus_mbar_GG.txt')
nsGG = np.loadtxt('data/maxTration_ns_GG.txt')


tick_size = 13
tick_sizey = 13
axis_size = 28
xaxis_size = 32
x_max = 100
label_size = 22
label_y_position = 1.01
ymax = 1.05
legend_size = 12

x_inset,y_inset = 0.9,0.9

#Histogram
fig = plt.figure(figsize=(15,5))
ax1 = plt.subplot(121)
plt.plot(nsER,meanTratioER,'o-')
plt.plot(nsSF,meanTratioSF,'o-')
plt.plot(nsBB,meanTratioBB,'o-')
plt.plot(nsBB,meanTratioGG,'o-')
#plt.title('ER graph')
plt.xlabel('$\\bar{m}$',fontsize=axis_size)
plt.ylabel('$\\langle T \\rangle_{RW}$ / $\\langle T \\rangle_{UE}$',fontsize=axis_size)
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)
ax1.spines["top"].set_visible(False)  
ax1.spines["right"].set_visible(False)
ax1.text(-0.025, label_y_position, 'a', transform=ax1.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
legend = ax1.legend(['Erdos Renyi', 'Scale free','Barbell','2D grid'],prop={'size': legend_size},
                    fancybox=True,loc='upper right', bbox_to_anchor=(0.85, 0.85))
plt.setp(legend.get_title(),fontsize=18)
plt.hlines(1,0,max(nsER),linestyle='dashed')



#Histogram
meanTratioKC = np.loadtxt('data/meanTratio_versus_mbar_KC.txt')
nsKC = np.loadtxt('data/maxTration_ns_KC.txt')

meanTratioCitation = np.loadtxt('data/meanTratio_versus_mbar_citation.txt')
ncCitation = np.loadtxt('data/maxTration_ns_citation.txt')

meanTratioManhattan = np.loadtxt('data/meanTratio_versus_mbar_NYC.txt')
nsManhattan = np.loadtxt('data/maxTration_ns_NYC.txt')


ax2 = plt.subplot(122)
plt.plot(nsKC,meanTratioKC,'o-')
plt.plot(ncCitation,meanTratioCitation,'o-')
plt.plot(nsManhattan,meanTratioManhattan,'o-')
plt.xlabel('$\\bar{m}$',fontsize=axis_size)
#plt.ylabel('$\\langle T \\rangle_{UE}$ / $\\langle T \\rangle_{RW}$',fontsize=axis_size)
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)
ax2.spines["top"].set_visible(False)  
ax2.spines["right"].set_visible(False)
ax2.text(-0.025, label_y_position, 'b', transform=ax2.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
legend = ax2.legend(['Karate club', 'Citation','Street network'],prop={'size': legend_size},
                    fancybox=True)
plt.setp(legend.get_title(),fontsize=18)
plt.hlines(1,0,max(nsER),linestyle='dashed')


plt.savefig('data/T_mbar_all_graphs_twopics.png')

# %%
2+2

# %% [markdown]
# ### Increasing sampling requirements

# %%
#Save data
mean_rw  = np.loadtxt('data/T_versus_mbar_ER_rw.txt')
err_rw = np.loadtxt('data/T_versus_mbar_ER_rw_error.txt')
mean_td  = np.loadtxt('data/T_versus_mbar_ER_td.txt')
err_td = np.loadtxt('data/T_versus_mbar_ER_td_error.txt')
ns = range(1,61,2)

tick_size=12
axis_size = 22



#Histogram
plt.figure(figsize=(12,4))
ax1 = plt.subplot(121)
plt.errorbar(ns,mean_rw,yerr=err_rw)
plt.errorbar(ns,mean_td,yerr=err_td)
#plt.title('ER graph')
plt.xlabel('$\\bar{m}$',fontsize=axis_size)
plt.ylabel('$ \\langle T_ \\rangle$',fontsize=axis_size)
plt.yticks(fontsize=tick_size)
ax1.spines["top"].set_visible(False)  
ax1.spines["right"].set_visible(False)
ax1.text(-0.025, label_y_position, 'a', transform=ax1.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
legend = ax1.legend(['Random walk', 'Urban explorer'],prop={'size': legend_size},
                    fancybox=True)
plt.setp(legend.get_title(),fontsize=18)
ax1.text(0.9, 0.15, '$p = 0.1$', transform=ax1.transAxes,
      fontsize=inset_size, va='top', ha='right')


p=0.8
mean_rw  = np.loadtxt('data/T_versus_mbar_ER_rw_p_'+str(p)+'.txt')
err_rw = np.loadtxt('data/T_versus_mbar_ER_rw_error_p_'+str(p)+'.txt')
mean_td  = np.loadtxt('data/T_versus_mbar_ER_td_p_'+str(p)+'.txt')
err_td = np.loadtxt('data/T_versus_mbar_ER_td_error_p_'+str(p)+'.txt')
ns = np.loadtxt('data/T_versus_mbar_ER_mbar_p_'+str(p)+'.txt')



ax2 = plt.subplot(122)
plt.errorbar(ns,mean_rw,yerr=err_rw)
plt.errorbar(ns,mean_td,yerr=err_td)
#plt.title('ER graph')
plt.xlabel('$\\bar{m}$',fontsize=axis_size)
plt.yticks(fontsize=tick_size)
ax2.spines["top"].set_visible(False)  
ax2.spines["right"].set_visible(False)
ax2.text(-0.025, label_y_position, 'b', transform=ax2.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
ax2.text(0.9, 0.15, '$p = 0.8$', transform=ax2.transAxes,
      fontsize=inset_size, va='top', ha='right')

plt.savefig('data/ER_meanT_versus_mbar.png')

# %% [markdown]
# ### $T_{max}$  and $C_{2*N}$

# %%
plt.errorbar(ns,mean_td,yerr=err_td)
plt.hlines(6000,0,60,linestyle='dashed')

# %%
maxTs_rw = np.loadtxt('data/Tmax_samples_rw.txt')
maxTs_td = np.loadtxt('data/Tmax_samples_td.txt')

# %% [markdown]
# ### Random Graphs
#
# I'm going to make the figures here

# %%
plt.figure(figsize=(12,9))

tick_size = 13
tick_sizey = 13
axis_size = 28
xaxis_size = 32
x_max = 100
label_size = 22
label_y_position = 1.10
ymax = 1
inset_size = 18
num_trials = 100;
mbar = 1
tick_size_x = 16
legend_size = 12


#Subplot1
Ts = np.loadtxt('data/T_versus_p_ER_Ts.png')
ps = np.loadtxt('data/T_versus_p_ER_ps.png')
ax1 = plt.subplot(221)
plt.plot(ps,Ts,'-o')
plt.xlabel('$p$',fontsize=axis_size-8)
plt.ylabel('$\\langle T \\rangle $',fontsize=axis_size)
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)
ax1.spines["top"].set_visible(False)  
ax1.spines["right"].set_visible(False)
ax1.text(-0.025, label_y_position, 'a', transform=ax1.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
legend = ax1.legend(['Erdos Renyi'],prop={'size': legend_size},
                    fancybox=True)
plt.setp(legend.get_title(),fontsize=18)
plt.hlines(1,0,max(ps),linestyle='dashed')


#Subplot2
Ts = np.loadtxt('data/T_versus_k_SF_Ts.png')
ks = np.loadtxt('data/T_versus_k_SF_ks.png')
ax2 = plt.subplot(222)
plt.plot(ks,Ts,'-o')
plt.xlabel('$k$',fontsize=axis_size-8)
plt.ylabel('$\\langle T \\rangle $',fontsize=axis_size)
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)
ax2.spines["top"].set_visible(False)  
ax2.spines["right"].set_visible(False)
ax2.text(-0.025, label_y_position, 'b', transform=ax2.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
legend = ax2.legend(['Scale free'],prop={'size': legend_size},
                    fancybox=True)
plt.hlines(1,0,max(ks),linestyle='dashed')




#Subplot 3
Trw = np.loadtxt('data/ER_scaling_Trw.txt')
Ttd = np.loadtxt('data/ER_scaling_Ttd.txt')
Ns = np.loadtxt('data/ER_scaling_Ns.txt')

ax3 = plt.subplot(223)
plt.plot(Ns,Trw,'o-')
plt.plot(Ns,Ttd,'o-')
plt.xlabel('$N$',fontsize=axis_size)
plt.ylabel('$ \\langle T \\rangle$',fontsize=axis_size)
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)
ax3.spines["top"].set_visible(False)  
ax3.spines["right"].set_visible(False)
ax3.text(-0.025, label_y_position, 'c', transform=ax4.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
legend = ax3.legend(['Random walk', 'Urban explorer'],prop={'size': legend_size},
                    fancybox=True)


#Subplot 4
Trw = np.loadtxt('data/SF_scaling_Trw.txt')
Ttd = np.loadtxt('data/SF_scaling_Ttd.txt')
Ns = np.loadtxt('data/SF_scaling_Ns.txt')

ax4 = plt.subplot(224)
plt.plot(Ns,Trw,'o-')
plt.plot(Ns,Ttd,'o-')
plt.xlabel('$N$',fontsize=axis_size)
plt.ylabel('$ \\langle T \\rangle$',fontsize=axis_size)
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)
ax4.spines["top"].set_visible(False)  
ax4.spines["right"].set_visible(False)
ax4.text(-0.025, label_y_position, 'd', transform=ax4.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
legend = ax4.legend(['Random walk', 'Urban explorer'],prop={'size': legend_size},
                    fancybox=True)
#ax2.text(0.9, 0.15, '$p = 0.8$', transform=ax2.transAxes,
#      fontsize=inset_size, va='top', ha='right')


plt.savefig('data/ER_scalefree_stats.png')

# %% [markdown]
# ### Scaling

# %%
plt.figure(figsize=(12,9))

tick_size = 13
tick_sizey = 13
axis_size = 28
xaxis_size = 32
x_max = 100
label_size = 22
label_y_position = 1.10
ymax = 1
inset_size = 18
num_trials = 100;
mbar = 1
tick_size_x = 16
legend_size = 12
inset_xpos, inset_ypos = 0.3,0.85

#Subplot1
Trw = np.loadtxt('data/ER_scaling_Trw.txt')
Ttd = np.loadtxt('data/ER_scaling_Ttd.txt')
Ns = np.loadtxt('data/ER_scaling_Ns.txt')
ax1 = plt.subplot(221)
plt.plot(Ns,Trw,'o-')
plt.plot(Ns,Ttd,'o-')
plt.ylabel('$\\langle T \\rangle $',fontsize=axis_size)
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)
ax1.spines["top"].set_visible(False)  
ax1.spines["right"].set_visible(False)
ax1.text(-0.025, label_y_position, 'a', transform=ax1.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
legend = ax1.legend(['Random walk', 'Urban explorer'],prop={'size': legend_size},
                    fancybox=True,loc=4)
plt.setp(legend.get_title(),fontsize=18)
ax1.text(inset_xpos+0.1, inset_ypos, 'Erdos Renyi', transform=ax1.transAxes,
      fontsize=inset_size, va='top', ha='right')



#Subplot2
Trw = np.loadtxt('data/SF_scaling_Trw.txt')
Ttd = np.loadtxt('data/SF_scaling_Ttd.txt')
Ns = np.loadtxt('data/SF_scaling_Ns.txt')
ax2 = plt.subplot(222)
plt.plot(Ns,Trw,'o-')
plt.plot(Ns,Ttd,'o-')
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)
ax2.spines["top"].set_visible(False)  
ax2.spines["right"].set_visible(False)
ax2.text(-0.025, label_y_position, 'b', transform=ax2.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
ax2.text(inset_xpos+0.1, inset_ypos, 'Scale free', transform=ax2.transAxes,
      fontsize=inset_size, va='top', ha='right')




#Subplot 3
Trw = np.loadtxt('data/BB_scaling_Trw.txt')
Ttd = np.loadtxt('data/BB_scaling_Ttd.txt')
Ns = np.loadtxt('data/BB_scaling_Ns.txt')

ax3 = plt.subplot(223)
plt.plot(Ns,Trw,'o-')
plt.plot(Ns,Ttd,'o-')
plt.xlabel('$N$',fontsize=axis_size)
plt.ylabel('$ \\langle T \\rangle$',fontsize=axis_size)
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)
ax3.spines["top"].set_visible(False)  
ax3.spines["right"].set_visible(False)
ax3.text(-0.025, label_y_position, 'c', transform=ax3.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
ax3.text(inset_xpos, inset_ypos, 'Barbell', transform=ax3.transAxes,
      fontsize=inset_size, va='top', ha='right')


#Subplot 4
Trw = np.loadtxt('data/GG_scaling_Trw.txt')
Ttd = np.loadtxt('data/GG_scaling_Ttd.txt')
Ns = np.loadtxt('data/GG_scaling_Ns.txt')

ax4 = plt.subplot(224)
plt.plot(Ns,Trw,'o-')
plt.plot(Ns,Ttd,'o-')
plt.xlabel('$N$',fontsize=axis_size)
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)
ax4.spines["top"].set_visible(False)  
ax4.spines["right"].set_visible(False)
ax4.text(-0.025, label_y_position, 'd', transform=ax4.transAxes,
      fontsize=label_size, fontweight='bold', va='top', ha='right')
ax4.text(inset_xpos, inset_ypos, '2D Grid', transform=ax4.transAxes,
      fontsize=inset_size, va='top', ha='right')


plt.savefig('data/random_graphs_scaling.png')
